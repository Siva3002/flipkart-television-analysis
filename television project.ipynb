# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
url="https://www.flipkart.com/search?q=television"

# %%
response=requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
pagecontent=response.text

# %%
soup=BeautifulSoup(pagecontent)

# %%
html_data = """
<div data-id="COMG9VHHF6HVJPP9" style="width: 100%;">
</div>
"""

# %%
pname=soup.find("div",attrs={"class":"RG5Slk"})

# %%
pname
# Out:
# <div class="RG5Slk">Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED Smart WebOS TV 2026 Edition with 2.1CH Audio System Tun...</div>

# %%
productname=[]

for x in soup.find_all('div',attrs={'class':'RG5Slk'}):
    productname.append(x.text if x else np.nan)

for name in productname:
    print(name)
# Out:
# Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED Smart WebOS TV 2026 Edition with 2.1CH Audio System Tun...
# Wobble K Series 138.7 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2025 Edition with MEMC Dolby Visi...
# Foxsky 60 cm (24 inch) HD Ready LED Smart Android TV 2025 Edition
# realme TechLife 80 cm (32 inch) QLED HD Ready Smart Google TV 2025 Edition
# Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED Smart WebOS TV 2026 Edition with 2.1CH Audio System Tun...
# Foxsky 165.1 cm (65 inch) Ultra HD (4K) Mini LED Smart WebOS TV 2026 Edition with 2.1CH Audio System T...
# XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smart Google TV with Dolby Vision | HDR 10 | 30W Dolby Audio...
# XIAOMI Fire Tv 80 cm (32 inch) HD Ready LED Smart Fire TV with High-Definition Display | Dolby Surroun...
# realme TechLife 126 cm (50 inch) Ultra HD (4K) LED Smart Google TV 2025 Edition
# Samsung 80 cm (32 Inch) HD Ready LED Smart Tizen TV with Bezel-Free Design | PurColor | Hyper Real Pic...
# Foxsky 139.7 cm (55 inch) Ultra HD (4K) Mini LED Smart WebOS TV 2026 Edition with 2.1CH Audio System T...
# Thomson NeoX 139 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 70W Sound Output po...
# VW OptimaX Series 101 cm (40 inch) QLED Full HD Smart Android TV 2025 Edition
# VW OptimaX Series 109 cm (43 inch) QLED Full HD Smart Android TV 2025 Edition
# iFFALCON by TCL U65 138 cm (55 inch) Ultra HD (4K) LED Smart Google TV 2025 Edition with MEMC | Dolby ...
# Samsung Crystal Vision 4K iSmart 138 cm (55 inch) Ultra HD (4K) LED Smart Tizen TV with IOT Sensors fo...
# PHILIPS 164 cm (65 inch) Ultra HD (4K) Mini LED Smart Google TV 2025 Edition with Local Dimming Dolby ...
# Blaupunkt 189 cm (75 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 80W Sound Output | 4 S...
# Coocaa S4U Plus 126 cm (50 inch) Full HD LED Smart Coolita TV 2025 Edition with Dolby Audio| Narrow Fr...
# Foxsky 60 cm (24 inch) HD Ready LED TV
# Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 80W Sound Outpu...
# Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with 70W Sound Output po...
# TCL T89C 139 cm (55 inch) QLED Ultra HD (4K) Smart Google TV 2025 Edition with HVA Panel | Dolby Visio...
# LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K) LED Smart WebOS TV 2025 Edition with Alpha7 AI Processo...

# %%
ratings=soup.find("div",attrs={"class":"MKiFS6"})

# %%
ratings
# Out:
# <div class="MKiFS6">4.1<img class="PZfbSE" src="..."/></div>

# %%
ratings=[]

for x in soup.find_all('div',attrs={'class':'MKiFS6'}):
   ratings.append(x.text if x else np.nan)

for name in ratings:
    print(name)
# Out:
# 4.1
# 4.3
# 4.3
# 4.3
# 4.2
# 4.3
# 3.8
# 3.9
# 3.9
# 4.1
# 4.3
# 4.2
# 3.8
# 4.1
# 4
# 3.8
# 3.8
# 4.1
# 4.4
# 4.3
# 5
# 2
# 4.3
# 4
# 5
# 4.1
# 5
# 5
# 3.8
# 5
# 5
# 4.2
# 4
# 4

# %%
for i in range(1,100):
    url=f"https://www.flipkart.com/search?q=television"
    print(url)
# Out:
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television
# https://www.flipkart.com/search?q=television

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import time

productname = [] 
price = []
rating = []
features = []
pagenum = []
original_price = []
Discount = []
Review = []

total_time = time.time()

for i in range(1,106): 
    start_time = time.time()
    URL = f"https://www.flipkart.com/search?q=television"
    page = requests.get(URL)
    soup = BeautifulSoup(page.text, "html.parser")

    for x in soup.find_all('div', attrs={'class':'ZFwe0M row'}):
        pname = x.find('div', attrs={'class':'RG5Slk'})
        cost = x.find('div', attrs={'class':'hZ3P6w DeU9vF'})   # discounted price
        rat = x.find('div', attrs={'class':'MKiFS6'})
        specs = x.find('div', attrs={'class':'CMXw7N'})
        op = x.find('div', attrs={'class':'kRYCnD gxR4EY'})
        discount = x.find('div', attrs={'class':'HQe8jr'})
        reviews = x.find('span', attrs={'class':'PvbNMB'})
        

        productname.append(pname.text if pname else np.nan)
        price.append(cost.text if cost else np.nan)
        rating.append(rat.text if rat else np.nan)
        features.append(specs.text if specs else np.nan)
        original_price.append(op.text if op else np.nan)
        Discount.append(discount.text if discount else np.nan)
        Review.append(reviews.text if reviews else np.nan)
        
        pagenum.append(i)

    print(f'Page {i} completed in {time.time()-start_time:.2f} seconds')

print("Total Time Completed in seconds", str(time.time()-total_time))
# Out:
# Page 1 completed in 1.29 seconds
# Page 2 completed in 1.11 seconds
# Page 3 completed in 1.12 seconds
# Page 4 completed in 1.17 seconds
# Page 5 completed in 1.06 seconds
# Page 6 completed in 1.48 seconds
# Page 7 completed in 1.03 seconds
# Page 8 completed in 1.11 seconds
# Page 9 completed in 1.18 seconds
# Page 10 completed in 1.04 seconds
# Page 11 completed in 1.07 seconds
# Page 12 completed in 1.15 seconds
# Page 13 completed in 1.06 seconds
# Page 14 completed in 1.05 seconds
# Page 15 completed in 1.05 seconds
# Page 16 completed in 1.66 seconds
# Page 17 completed in 1.02 seconds
# Page 18 completed in 1.36 seconds
# Page 19 completed in 1.03 seconds
# Page 20 completed in 1.07 seconds
# Page 21 completed in 1.08 seconds
# Page 22 completed in 1.21 seconds
# Page 23 completed in 1.04 seconds
# Page 24 completed in 1.02 seconds
# Page 25 completed in 1.09 seconds
# Page 26 completed in 1.54 seconds
# Page 27 completed in 1.25 seconds
# Page 28 completed in 1.43 seconds
# Page 29 completed in 1.45 seconds
# Page 30 completed in 1.09 seconds
# Page 31 completed in 1.00 seconds
# Page 32 completed in 1.03 seconds
# Page 33 completed in 1.05 seconds
# Page 34 completed in 1.05 seconds
# Page 35 completed in 1.04 seconds
# Page 36 completed in 1.52 seconds
# Page 37 completed in 1.10 seconds
# Page 38 completed in 1.01 seconds
# Page 39 completed in 1.06 seconds
# Page 40 completed in 1.06 seconds
# Page 41 completed in 1.28 seconds
# Page 42 completed in 1.01 seconds
# Page 43 completed in 1.35 seconds
# Page 44 completed in 1.09 seconds
# Page 45 completed in 1.06 seconds
# Page 46 completed in 1.07 seconds
# Page 47 completed in 1.46 seconds
# Page 48 completed in 1.07 seconds
# Page 49 completed in 1.10 seconds
# Page 50 completed in 0.99 seconds
# Page 51 completed in 1.23 seconds
# Page 52 completed in 1.04 seconds
# Page 53 completed in 1.08 seconds
# Page 54 completed in 1.06 seconds
# Page 55 completed in 1.27 seconds
# Page 56 completed in 1.11 seconds
# Page 57 completed in 1.51 seconds
# Page 58 completed in 1.16 seconds
# Page 59 completed in 1.12 seconds
# Page 60 completed in 1.34 seconds
# Page 61 completed in 1.05 seconds
# Page 62 completed in 1.19 seconds
# Page 63 completed in 1.17 seconds
# Page 64 completed in 1.07 seconds
# Page 65 completed in 1.10 seconds
# Page 66 completed in 1.16 seconds
# Page 67 completed in 1.69 seconds
# Page 68 completed in 1.06 seconds
# Page 69 completed in 1.20 seconds
# Page 70 completed in 1.17 seconds
# Page 71 completed in 1.14 seconds
# Page 72 completed in 1.14 seconds
# Page 73 completed in 1.09 seconds
# Page 74 completed in 1.17 seconds
# Page 75 completed in 1.15 seconds
# Page 76 completed in 1.06 seconds
# Page 77 completed in 1.62 seconds
# Page 78 completed in 1.28 seconds
# Page 79 completed in 1.23 seconds
# Page 80 completed in 1.01 seconds
# Page 81 completed in 1.11 seconds
# Page 82 completed in 1.12 seconds
# Page 83 completed in 1.45 seconds
# Page 84 completed in 1.22 seconds
# Page 85 completed in 1.31 seconds
# Page 86 completed in 1.32 seconds
# Page 87 completed in 1.52 seconds
# Page 88 completed in 1.16 seconds
# Page 89 completed in 1.14 seconds
# Page 90 completed in 1.02 seconds
# Page 91 completed in 1.07 seconds
# Page 92 completed in 1.03 seconds
# Page 93 completed in 1.03 seconds
# Page 94 completed in 1.06 seconds
# Page 95 completed in 1.16 seconds
# Page 96 completed in 1.08 seconds
# Page 97 completed in 1.67 seconds
# Page 98 completed in 1.01 seconds
# Page 99 completed in 1.31 seconds
# Page 100 completed in 1.07 seconds
# Page 101 completed in 1.16 seconds
# Page 102 completed in 1.21 seconds
# Page 103 completed in 1.46 seconds
# Page 104 completed in 1.09 seconds
# Page 105 completed in 1.29 seconds
# Total Time Completed in seconds 123.51633548736572

# %%
television_df = pd.DataFrame({
   "productname": productname,
   "productprice": price,
   "product_rating": rating,
   "product_features": features,
   "product_orginal_price":original_price,
   "product_Discount": Discount,
   "product_reviews": Review,
})

# %%
television_df
# Out:
#                                             productname productprice  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...      ₹19,999
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...      ₹29,499
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...       ₹5,499
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...       ₹9,999
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...      ₹24,999
# ...                                                 ...          ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV       ₹4,999
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...      ₹32,999
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...      ₹43,999
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...      ₹28,990
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...      ₹21,499
#
#      product_rating                                   product_features  \
# 0               NaN  Ultra HD (4K) | Mini LEDModel ID: FS43MINILEDL...
# 1               NaN  Ultra HD (4K) | LEDModel ID: WB55UDAGU2875D25L...
# 2               4.1  HD Ready | LEDModel ID: 24 FSELS PROLaunch Yea...
# 3               4.3  HD Ready | QLEDModel ID: 32HDGQRDDAQLaunch Yea...
# 4               NaN  Ultra HD (4K) | Mini LEDModel ID: FS50MINILEDL...
# ...             ...                                                ...
# 2515              4  HD Ready | LEDModel ID: 24FSNLaunch Year: 2023...
# 2516            3.8  Ultra HD (4K) | QLEDModel ID: 55SQ0707Launch Y...
# 2517            3.8  Ultra HD (4K) | QLEDModel ID: 65NEOX0009Launch...
# 2518            4.4  Ultra HD (4K) | LEDModel ID: 43UA82006LALaunch...
# 2519            4.3  Ultra HD (4K) | LEDModel ID: L43MB-FINLaunch Y...
#
#      product_orginal_price product_Discount                 product_reviews
# 0                  ₹49,990          59% off                             NaN
# 1                  ₹73,999          60% off                             NaN
# 2                   ₹9,990          44% off  16,424 Ratings & 3,041 Reviews
# 3                  ₹23,999          58% off  19,943 Ratings & 1,542 Reviews
# 4                  ₹59,999          58% off                             NaN
# ...                    ...              ...                             ...
# 2515               ₹12,999          61% off     5,484 Ratings & 658 Reviews
# 2516               ₹49,999          34% off         60 Ratings & 17 Reviews
# 2517               ₹69,999          37% off          80 Ratings & 9 Reviews
# 2518               ₹46,090          37% off  36,267 Ratings & 2,455 Reviews
# 2519               ₹37,999          43% off  83,751 Ratings & 6,182 Reviews
#
# [2520 rows x 7 columns]

# %%
television_df.to_csv("Flipkart_television.csv",index=False)

# %%
df=pd.read_csv("Flipkart_television.csv")

# %%
df
# Out:
#                                             productname productprice  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...      ₹19,999
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...      ₹29,499
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...       ₹5,499
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...       ₹9,999
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...      ₹24,999
# ...                                                 ...          ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV       ₹4,999
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...      ₹32,999
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...      ₹43,999
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...      ₹28,990
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...      ₹21,499
#
#       product_rating                                   product_features  \
# 0                NaN  Ultra HD (4K) | Mini LEDModel ID: FS43MINILEDL...
# 1                NaN  Ultra HD (4K) | LEDModel ID: WB55UDAGU2875D25L...
# 2                4.1  HD Ready | LEDModel ID: 24 FSELS PROLaunch Yea...
# 3                4.3  HD Ready | QLEDModel ID: 32HDGQRDDAQLaunch Yea...
# 4                NaN  Ultra HD (4K) | Mini LEDModel ID: FS50MINILEDL...
# ...              ...                                                ...
# 2515             4.0  HD Ready | LEDModel ID: 24FSNLaunch Year: 2023...
# 2516             3.8  Ultra HD (4K) | QLEDModel ID: 55SQ0707Launch Y...
# 2517             3.8  Ultra HD (4K) | QLEDModel ID: 65NEOX0009Launch...
# 2518             4.4  Ultra HD (4K) | LEDModel ID: 43UA82006LALaunch...
# 2519             4.3  Ultra HD (4K) | LEDModel ID: L43MB-FINLaunch Y...
#
#      product_orginal_price product_Discount                 product_reviews
# 0                  ₹49,990          59% off                             NaN
# 1                  ₹73,999          60% off                             NaN
# 2                   ₹9,990          44% off  16,424 Ratings & 3,041 Reviews
# 3                  ₹23,999          58% off  19,943 Ratings & 1,542 Reviews
# 4                  ₹59,999          58% off                             NaN
# ...                    ...              ...                             ...
# 2515               ₹12,999          61% off     5,484 Ratings & 658 Reviews
# 2516               ₹49,999          34% off         60 Ratings & 17 Reviews
# 2517               ₹69,999          37% off          80 Ratings & 9 Reviews
# 2518               ₹46,090          37% off  36,267 Ratings & 2,455 Reviews
# 2519               ₹37,999          43% off  83,751 Ratings & 6,182 Reviews
#
# [2520 rows x 7 columns]

# %%
len(name)
len(price)
len(rating)
len(features)
len(pagenum)
len(original_price)
len(Discount)
len(Review)
# Out:
# 2520

# %%
television_df=pd.DataFrame({"product_name":productname,"price":price,"rating":rating,"pagenum":pagenum,
                              "original_price":original_price,"Discount":Discount,"Review":Review})

# %%
television_df
# Out:
#                                            product_name    price rating  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  ₹19,999    NaN
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  ₹29,499    NaN
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   ₹5,499    4.1
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...   ₹9,999    4.3
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  ₹24,999    NaN
# ...                                                 ...      ...    ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999      4
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...  ₹32,999    3.8
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...  ₹43,999    3.8
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...  ₹28,990    4.4
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...  ₹21,499    4.3
#
#       pagenum original_price Discount                          Review
# 0           1        ₹49,990  59% off                             NaN
# 1           1        ₹73,999  60% off                             NaN
# 2           1         ₹9,990  44% off  16,424 Ratings & 3,041 Reviews
# 3           1        ₹23,999  58% off  19,943 Ratings & 1,542 Reviews
# 4           1        ₹59,999  58% off                             NaN
# ...       ...            ...      ...                             ...
# 2515      105        ₹12,999  61% off     5,484 Ratings & 658 Reviews
# 2516      105        ₹49,999  34% off         60 Ratings & 17 Reviews
# 2517      105        ₹69,999  37% off          80 Ratings & 9 Reviews
# 2518      105        ₹46,090  37% off  36,267 Ratings & 2,455 Reviews
# 2519      105        ₹37,999  43% off  83,751 Ratings & 6,182 Reviews
#
# [2520 rows x 7 columns]

# %%
television_df.to_csv("television.csv",index=False)

# %%
df=pd.read_csv("television.csv")

# %%
df
# Out:
#                                            product_name    price  rating  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  ₹19,999     NaN
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  ₹29,499     NaN
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   ₹5,499     4.1
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...   ₹9,999     4.3
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  ₹24,999     NaN
# ...                                                 ...      ...     ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...  ₹32,999     3.8
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...  ₹43,999     3.8
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...  ₹28,990     4.4
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...  ₹21,499     4.3
#
#       pagenum original_price Discount                          Review
# 0           1        ₹49,990  59% off                             NaN
# 1           1        ₹73,999  60% off                             NaN
# 2           1         ₹9,990  44% off  16,424 Ratings & 3,041 Reviews
# 3           1        ₹23,999  58% off  19,943 Ratings & 1,542 Reviews
# 4           1        ₹59,999  58% off                             NaN
# ...       ...            ...      ...                             ...
# 2515      105        ₹12,999  61% off     5,484 Ratings & 658 Reviews
# 2516      105        ₹49,999  34% off         60 Ratings & 17 Reviews
# 2517      105        ₹69,999  37% off          80 Ratings & 9 Reviews
# 2518      105        ₹46,090  37% off  36,267 Ratings & 2,455 Reviews
# 2519      105        ₹37,999  43% off  83,751 Ratings & 6,182 Reviews
#
# [2520 rows x 7 columns]

# %%
df.shape
# Out:
# (2520, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_name    2520 non-null   object
#  1   price           2520 non-null   object
#  2   rating          2006 non-null   float64
#  3   pagenum         2520 non-null   int64
#  4   original_price  2520 non-null   object
#  5   Discount        2520 non-null   object
#  6   Review          2006 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.9+ KB

# %%
df.isnull().sum()
# Out:
# product_name        0
# price               0
# rating            514
# pagenum             0
# original_price      0
# Discount            0
# Review            514
# dtype: int64

# %%
df.head()
# Out:
#                                         product_name    price  rating  \
# 0  Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  ₹19,999     NaN
# 1  Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  ₹29,499     NaN
# 2  Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   ₹5,499     4.1
# 3  realme TechLife 80 cm (32 inch) QLED HD Ready ...   ₹9,999     4.3
# 4  Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  ₹24,999     NaN
#
#    pagenum original_price Discount                          Review
# 0        1        ₹49,990  59% off                             NaN
# 1        1        ₹73,999  60% off                             NaN
# 2        1         ₹9,990  44% off  16,424 Ratings & 3,041 Reviews
# 3        1        ₹23,999  58% off  19,943 Ratings & 1,542 Reviews
# 4        1        ₹59,999  58% off                             NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   product_name    2520 non-null   object
#  1   price           2520 non-null   object
#  2   rating          2006 non-null   float64
#  3   pagenum         2520 non-null   int64
#  4   original_price  2520 non-null   object
#  5   Discount        2520 non-null   object
#  6   Review          2006 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 137.9+ KB

# %%
print(df.isnull().sum())
# Out:
# product_name        0
# price               0
# rating            514
# pagenum             0
# original_price      0
# Discount            0
# Review            514
# dtype: int64

# %%
# df.drop(columns=['features'], inplace=True)

# %%
# Remove non-numeric characters and convert to float
df['Discount'] = df['Discount'].str.extract('(\d+)').astype(float)

df['Review'] = df['Review'].str.replace(',', '').str.extract('(\d+)').astype(float)

# %%
df.isnull().sum()
# Out:
# product_name        0
# price               0
# rating            514
# pagenum             0
# original_price      0
# Discount            0
# Review            514
# dtype: int64

# %%
df["original_price"].value_counts()
# Out:
# original_price
# ₹24,999      210
# ₹49,999      206
# ₹69,999      204
# ₹9,990       105
# ₹23,999      105
# ₹46,090      105
# ₹12,999      105
# ₹44,999      105
# ₹56,199      105
# ₹18,900      105
# ₹20,999      105
# ₹66,599      105
# ₹67,200      105
# ₹35,999      105
# ₹49,990      103
# ₹73,999      103
# ₹1,29,999    103
# ₹99,999      103
# ₹1,43,990    103
# ₹59,999      103
# ₹98,990       66
# ₹37,999       41
# ₹84,999        2
# ₹45,899        2
# ₹21,240        2
# ₹84,590        2
# ₹17,900        2
# ₹26,999        2
# ₹41,300        2
# ₹21,999        2
# ₹17,999        2
# ₹15,000        2
# Name: count, dtype: int64

# %%
df["original_price"].fillna(df["original_price"].mode()[0],inplace = True)

# %%
df["Discount"].value_counts()
# Out:
# Discount
# 59.0    210
# 58.0    210
# 36.0    210
# 37.0    207
# 60.0    169
# 61.0    107
# 51.0    107
# 41.0    107
# 46.0    105
# 47.0    105
# 63.0    105
# 45.0    105
# 52.0    105
# 44.0    105
# 40.0    103
# 49.0    103
# 69.0    103
# 34.0    103
# 57.0    102
# 43.0     43
# 21.0      2
# 31.0      2
# 65.0      2
# Name: count, dtype: int64

# %%
df["Discount"].fillna(df["Discount"].mode()[0],inplace = True)

# %%
df.isnull().sum()
# Out:
# product_name        0
# price               0
# rating            514
# pagenum             0
# original_price      0
# Discount            0
# Review            514
# dtype: int64

# %%
df.head()
# Out:
#                                         product_name    price  rating  \
# 0  Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  ₹19,999     NaN
# 1  Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  ₹29,499     NaN
# 2  Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   ₹5,499     4.1
# 3  realme TechLife 80 cm (32 inch) QLED HD Ready ...   ₹9,999     4.3
# 4  Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  ₹24,999     NaN
#
#    pagenum original_price  Discount   Review
# 0        1        ₹49,990      59.0      NaN
# 1        1        ₹73,999      60.0      NaN
# 2        1         ₹9,990      44.0  16424.0
# 3        1        ₹23,999      58.0  19943.0
# 4        1        ₹59,999      58.0      NaN

# %%
null=df[df['price'].isnull()].index

# %%
df[df['price'].isnull()].index
# Out:
# Index([], dtype='int64')

# %%
df['price'].fillna(14000, inplace=True)

# %%
df.isnull().sum()
# Out:
# product_name        0
# price               0
# rating            514
# pagenum             0
# original_price      0
# Discount            0
# Review            514
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['product_name']
# Out:
# 0       Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...
# 1       Wobble K Series 138.7 cm (55 inch) Ultra HD (4...
# 2       Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...
# 3       realme TechLife 80 cm (32 inch) QLED HD Ready ...
# 4       Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...
#                               ...
# 2515               Foxsky 60 cm (24 inch) HD Ready LED TV
# 2516    Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...
# 2517    Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...
# 2518    LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...
# 2519    XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...
# Name: product_name, Length: 2520, dtype: object

# %%
import re
df["Brand"]=df["product_name"].apply(lambda x:re.findall(r"^\w+",x)[0])

# %%
df["product_name"].apply(lambda x:re.findall(r"^\w+",x)[0])
# Out:
# 0          Foxsky
# 1          Wobble
# 2          Foxsky
# 3          realme
# 4          Foxsky
#           ...
# 2515       Foxsky
# 2516    Blaupunkt
# 2517      Thomson
# 2518           LG
# 2519       XIAOMI
# Name: product_name, Length: 2520, dtype: object

# %%
df["Brand"]
# Out:
# 0          Foxsky
# 1          Wobble
# 2          Foxsky
# 3          realme
# 4          Foxsky
#           ...
# 2515       Foxsky
# 2516    Blaupunkt
# 2517      Thomson
# 2518           LG
# 2519       XIAOMI
# Name: Brand, Length: 2520, dtype: object

# %%
df["Brand"].value_counts().head()
# Out:
# Brand
# Foxsky     621
# XIAOMI     253
# Samsung    214
# realme     210
# VW         210
# Name: count, dtype: int64

# %%
df['screen_size_inch']=df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])

# %%
 df['product_name'].apply(lambda x: re.findall(r"\b\d+\s*L\b", x)[0] if re.findall(r"\b\d+\s*L\b", x) else None)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2515    None
# 2516    None
# 2517    None
# 2518    None
# 2519    None
# Name: product_name, Length: 2520, dtype: object

# %%
df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])
# Out:
# 0        109
# 1        138
# 2         60
# 3         80
# 4        127
#         ...
# 2515      60
# 2516     139
# 2517     164
# 2518    8200
# 2519     108
# Name: product_name, Length: 2520, dtype: object

# %%
df['screen_size_inch']=df["product_name"].apply(lambda x:re.findall(r"\d+",x)[0])

# %%
df
# Out:
#                                            product_name    price  rating  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  ₹19,999     NaN
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  ₹29,499     NaN
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   ₹5,499     4.1
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...   ₹9,999     4.3
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  ₹24,999     NaN
# ...                                                 ...      ...     ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV   ₹4,999     4.0
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...  ₹32,999     3.8
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...  ₹43,999     3.8
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...  ₹28,990     4.4
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...  ₹21,499     4.3
#
#       pagenum original_price  Discount   Review      Brand screen_size_inch
# 0           1        ₹49,990      59.0      NaN     Foxsky              109
# 1           1        ₹73,999      60.0      NaN     Wobble              138
# 2           1         ₹9,990      44.0  16424.0     Foxsky               60
# 3           1        ₹23,999      58.0  19943.0     realme               80
# 4           1        ₹59,999      58.0      NaN     Foxsky              127
# ...       ...            ...       ...      ...        ...              ...
# 2515      105        ₹12,999      61.0   5484.0     Foxsky               60
# 2516      105        ₹49,999      34.0     60.0  Blaupunkt              139
# 2517      105        ₹69,999      37.0     80.0    Thomson              164
# 2518      105        ₹46,090      37.0  36267.0         LG             8200
# 2519      105        ₹37,999      43.0  83751.0     XIAOMI              108
#
# [2520 rows x 9 columns]

# %%
df["price"] = df["price"].astype(str).apply(lambda x: x[1:] if x.startswith("₹") else x)

# %%
df["price"]
# Out:
# 0       19,999
# 1       29,499
# 2        5,499
# 3        9,999
# 4       24,999
#          ...
# 2515     4,999
# 2516    32,999
# 2517    43,999
# 2518    28,990
# 2519    21,499
# Name: price, Length: 2520, dtype: object

# %%
df["price"]=df["price"].apply(lambda x:re.sub(r",","",x))

# %%
df["price"]
# Out:
# 0       19999
# 1       29499
# 2        5499
# 3        9999
# 4       24999
#         ...
# 2515     4999
# 2516    32999
# 2517    43999
# 2518    28990
# 2519    21499
# Name: price, Length: 2520, dtype: object

# %%
df["price"]=df["price"].astype("int")

# %%
df["original_price"]
# Out:
# 0       ₹49,990
# 1       ₹73,999
# 2        ₹9,990
# 3       ₹23,999
# 4       ₹59,999
#          ...
# 2515    ₹12,999
# 2516    ₹49,999
# 2517    ₹69,999
# 2518    ₹46,090
# 2519    ₹37,999
# Name: original_price, Length: 2520, dtype: object

# %%
df["original_price"].apply(lambda x:x[1:])
# Out:
# 0       49,990
# 1       73,999
# 2        9,990
# 3       23,999
# 4       59,999
#          ...
# 2515    12,999
# 2516    49,999
# 2517    69,999
# 2518    46,090
# 2519    37,999
# Name: original_price, Length: 2520, dtype: object

# %%
df["original_price"]=df["original_price"].apply(lambda x:x[1:])

# %%
df["original_price"]=df["original_price"].apply(lambda x:re.sub(r",","",x))

# %%
df["original_price"]=df["original_price"].astype("int")

# %%
df.dtypes
# Out:
# product_name         object
# price                 int32
# rating              float64
# pagenum               int64
# original_price        int32
# Discount            float64
# Review              float64
# Brand                object
# screen_size_inch     object
# dtype: object

# %%
if 'capacity_liters' in df.columns:
    df.drop(columns=['capacity_liters'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      2520 non-null   object
#  1   price             2520 non-null   int32
#  2   rating            2006 non-null   float64
#  3   pagenum           2520 non-null   int64
#  4   original_price    2520 non-null   int32
#  5   Discount          2520 non-null   float64
#  6   Review            2006 non-null   float64
#  7   Brand             2520 non-null   object
#  8   screen_size_inch  2520 non-null   object
# dtypes: float64(3), int32(2), int64(1), object(3)
# memory usage: 157.6+ KB

# %%
df['product_name'].head(10)
# Out:
# 0    Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...
# 1    Wobble K Series 138.7 cm (55 inch) Ultra HD (4...
# 2    Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...
# 3    realme TechLife 80 cm (32 inch) QLED HD Ready ...
# 4    Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...
# 5    Foxsky 165.1 cm (65 inch) Ultra HD (4K) Mini L...
# 6    XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...
# 7    XIAOMI Fire Tv 80 cm (32 inch) HD Ready LED Sm...
# 8    realme TechLife 126 cm (50 inch) Ultra HD (4K)...
# 9    Samsung 80 cm (32 Inch) HD Ready LED Smart Tiz...
# Name: product_name, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      2520 non-null   object
#  1   price             2520 non-null   int32
#  2   rating            2006 non-null   float64
#  3   pagenum           2520 non-null   int64
#  4   original_price    2520 non-null   int32
#  5   Discount          2520 non-null   float64
#  6   Review            2006 non-null   float64
#  7   Brand             2520 non-null   object
#  8   screen_size_inch  2520 non-null   object
# dtypes: float64(3), int32(2), int64(1), object(3)
# memory usage: 157.6+ KB

# %%
df.shape
# Out:
# (2520, 9)

# %%
df
# Out:
#                                            product_name  price  rating  \
# 0     Foxsky 109 cm (43 inch) Ultra HD (4K) Mini LED...  19999     NaN
# 1     Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  29499     NaN
# 2     Foxsky 60 cm (24 inch) HD Ready LED Smart Andr...   5499     4.1
# 3     realme TechLife 80 cm (32 inch) QLED HD Ready ...   9999     4.3
# 4     Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  24999     NaN
# ...                                                 ...    ...     ...
# 2515             Foxsky 60 cm (24 inch) HD Ready LED TV   4999     4.0
# 2516  Blaupunkt SonicQ 139 cm (55 inch) QLED Ultra H...  32999     3.8
# 2517  Thomson NeoX 164 cm (65 inch) QLED Ultra HD (4...  43999     3.8
# 2518  LG AI TV UA8200 108 cm (43 inch) Ultra HD (4K)...  28990     4.4
# 2519  XIAOMI F Series 108 cm (43 inch) Ultra HD (4K)...  21499     4.3
#
#       pagenum  original_price  Discount   Review      Brand screen_size_inch
# 0           1           49990      59.0      NaN     Foxsky              109
# 1           1           73999      60.0      NaN     Wobble              138
# 2           1            9990      44.0  16424.0     Foxsky               60
# 3           1           23999      58.0  19943.0     realme               80
# 4           1           59999      58.0      NaN     Foxsky              127
# ...       ...             ...       ...      ...        ...              ...
# 2515      105           12999      61.0   5484.0     Foxsky               60
# 2516      105           49999      34.0     60.0  Blaupunkt              139
# 2517      105           69999      37.0     80.0    Thomson              164
# 2518      105           46090      37.0  36267.0         LG             8200
# 2519      105           37999      43.0  83751.0     XIAOMI              108
#
# [2520 rows x 9 columns]

# %%
df.to_csv("cleaned_television.csv",index = False)

# %%
df = pd.read_csv("cleaned_television.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2520 entries, 0 to 2519
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_name      2520 non-null   object
#  1   price             2520 non-null   int64
#  2   rating            2006 non-null   float64
#  3   pagenum           2520 non-null   int64
#  4   original_price    2520 non-null   int64
#  5   Discount          2520 non-null   float64
#  6   Review            2006 non-null   float64
#  7   Brand             2520 non-null   object
#  8   screen_size_inch  2520 non-null   int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 177.3+ KB

# %%
df.shape
# Out:
# (2520, 9)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
brand_price = df.groupby("Brand")["price"].mean().sort_values(ascending=False)
print(brand_price)
# Out:
# Brand
# PHILIPS      59808.523810
# Blaupunkt    49499.000000
# TCL          38872.352941
# Thomson      37969.731707
# Wobble       29499.000000
# LG           28700.280374
# iFFALCON     23884.981308
# Samsung      22966.121495
# Foxsky       21463.573269
# XIAOMI       20394.256917
# Coocaa       17499.000000
# realme       16499.000000
# Infinix      12499.000000
# VW           12499.000000
# BESTON        7359.000000
# MarQ          5199.000000
# Name: price, dtype: float64

# %%
brand_rating = df.groupby("Brand")["rating"].mean().sort_values(ascending=False)
print(brand_rating)
# Out:
# Brand
# LG           4.400000
# Samsung      4.300000
# XIAOMI       4.297628
# realme       4.250000
# MarQ         4.200000
# PHILIPS      4.200000
# Coocaa       4.100000
# TCL          4.100000
# iFFALCON     4.100000
# Foxsky       4.050000
# Infinix      4.000000
# BESTON       3.900000
# VW           3.900000
# Blaupunkt    3.800000
# Thomson      3.800000
# Wobble            NaN
# Name: rating, dtype: float64

# %%
brand_discount = df.groupby("Brand")["Discount"].mean().sort_values(ascending=False)
print(brand_discount)
# Out:
# Brand
# MarQ         65.000000
# iFFALCON     62.962617
# Wobble       60.000000
# TCL          59.941176
# BESTON       59.000000
# realme       58.500000
# Foxsky       57.966184
# Coocaa       51.000000
# VW           45.500000
# XIAOMI       43.893281
# Samsung      43.663551
# Infinix      43.000000
# Blaupunkt    41.500000
# PHILIPS      40.019048
# LG           36.981308
# Thomson      36.497561
# Name: Discount, dtype: float64

# %%
df_20k_50k = df[(df["price"] >= 20000) & (df["price"] <= 60000)]
df_20k_50k.head()
# Out:
#                                         product_name  price  rating  pagenum  \
# 1  Wobble K Series 138.7 cm (55 inch) Ultra HD (4...  29499     NaN        1
# 4  Foxsky 127 cm (50 inch) Ultra HD (4K) Mini LED...  24999     NaN        1
# 5  Foxsky 165.1 cm (65 inch) Ultra HD (4K) Mini L...  43999     NaN        1
# 6  XIAOMI 125 cm (50 inch) Ultra HD (4K) LED Smar...  28499     4.3        1
# 8  realme TechLife 126 cm (50 inch) Ultra HD (4K)...  22999     4.2        1
#
#    original_price  Discount   Review   Brand  screen_size_inch
# 1           73999      60.0      NaN  Wobble               138
# 4           59999      58.0      NaN  Foxsky               127
# 5          143990      69.0      NaN  Foxsky               165
# 6           44999      36.0  83751.0  XIAOMI               125
# 8           56199      59.0    374.0  realme               126

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Bar Chart for Brand (Categorical)

df.columns = df.columns.str.strip()

counts = df["Brand"].value_counts().head(10)
plt.figure(figsize=(6, 4))
plt.bar(counts.index, counts.values, color='green', edgecolor='black')
plt.title("Top 10 Television Brands on Flipkart")
plt.xlabel("Brand")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show();

# %%
# Histogram for Price (Numerical)

plt.figure(figsize=(6, 4))
plt.hist(df['price'], bins=30, color='lightcoral', edgecolor='black')
plt.title("Distribution of Price")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show();

# %%
# Box Plot for Ratings(Numerical) 

plt.figure(figsize=(6, 4))
sns.boxplot(x=df['rating'], color='yellow')

plt.title("Box Plot of Ratings")
plt.xlabel("Rating")
plt.grid(False)
plt.show();

# %%
# Numerical vs. Numerical: Scatter Plot

df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='price', y='rating', color='red', alpha=0.6)

plt.title("Price vs. Rating")
plt.xlabel("Price")
plt.ylabel("Rating")
plt.show();

# %%
# Categorical vs. Numerical: Bar Plot
df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
avg_price_brand = df.groupby('Brand')['price'].mean().sort_values(ascending=False).head(10)
plt.bar(avg_price_brand.index, avg_price_brand.values, color='blue', edgecolor='black')
plt.title("Average Price by Top 10 Brands")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.xticks(rotation=45)
plt.show();

# %%
# Categorical vs. Numerical: Box Plot

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 4))

top_5_brands = df['Brand'].value_counts().nlargest(5).index
df_subset = df[df['Brand'].isin(top_5_brands)]

sns.boxplot(data=df_subset, x='Brand', y='price', palette='Set2')

plt.title("Price Distribution by Top 5 Brands")
plt.xlabel("Brand")
plt.ylabel("Price")
plt.grid(False)

plt.show();

# %%
# Numerical vs. Numerical : Heat map

df.columns = df.columns.str.strip()
numeric_cols = ['price','rating','original_price','Discount','Review','screen_size_inch']
correlation_matrix = df[numeric_cols].corr()

plt.figure(figsize=(6, 4))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',center=0,fmt=".2f")
plt.title('Correlation Matrix of television Features')
plt.show();

# %%
# Multivariate Scatter Plot
df.columns = df.columns.str.strip()

plt.figure(figsize=(6, 4))
sns.scatterplot(data=df, x='price', y='rating', hue='Brand', size='Discount', alpha=0.7)
plt.title("Price vs Rating by Brand & Discount")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') 
plt.show();
